# %% [markdown]
# **Task # 2 - To Explore
# Supervised Machine Learning**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = "https://bit.ly/w-data"
data = pd.read_csv(url)
print("Data Loaded")
data.head()
# Out:
# Data Loaded
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
data.hist(figsize=(10,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f329b470f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f329b3d8240>]],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
data.plot(x="Hours",y="Scores",c='g',style='^')
plt.title("Hours VS Score")
plt.xlabel("Total Hours Studied")
plt.ylabel("Total Scores Obtained")
plt.show()

# %%
X = data["Hours"].values
y = data["Scores"].values
X = X.reshape(-1,1)
y = y.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=4)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression().fit(X_train,y_train)

# %%
line = lr.coef_*X + lr.intercept_
plt.scatter(X,y,c='y')
plt.plot(X,line,c='r')
plt.show()

# %%
y_pred = lr.predict(X_test)

# %%
hour = 9.25
prediction = lr.predict([[hour]])
print(prediction)
# Out:
# [[94.43733048]]
